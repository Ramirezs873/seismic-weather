# %%
from obspy import read
import numpy as np
from matplotlib import pyplot as plt
import yaml

# %%
with open("config.yml", "r") as f:
    config = yaml.safe_load(f)

base = Path(config["aws_filepath"])
